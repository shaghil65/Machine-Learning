# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
dataset = pd.read_csv('ex1data2.txt', names = ['size', 'bedroom','price'])

# %%
data = dataset[['bedroom','price']]
data.head(5)
# Out:
#    bedroom   price
# 0        3  399900
# 1        3  329900
# 2        3  369000
# 3        2  232000
# 4        4  539900

# %%
X_df = pd.DataFrame(data['bedroom'])
y_df = pd.DataFrame(data['price'])
m = len(y_df)

# %%
# plt.figure(figsize=(8,6))
# plt.plot(X_df.bedroom, y_df, 'kx')
# plt.xlabel('bedroom')
# plt.ylabel('price')

sns.regplot(x=X_df, y=y_df, data=data, logistic=True, ci=None)
# Out:
# <Axes: xlabel='bedroom', ylabel='price'>

# %%
iter = 1000
alpha = 0.01

# %%
X_df['intercept'] = 1

# %%
X = np.array(X_df)
y = np.array(y_df).flatten()
theta = np.array([0, 0])

# %%
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# %%
def cost_function(X, y, theta):
    m = len(y)
    h = sigmoid(X.dot(theta))
    epsilon = 1e-10 
    J = -(1 / m) * np.sum(y * np.log(h + epsilon) + (1 - y) * np.log(1 - h + epsilon))
    return J

# %%
def gradient_descent(X, y, theta, alpha, iterations):
    m = len(y)
    cost_history = []

    for iteration in range(iterations):
        hypothesis = sigmoid(X.dot(theta))
        loss = hypothesis - y
        gradient = X.T.dot(loss) / m
        theta = theta - alpha * gradient
        cost = cost_function(X, y, theta)
        cost_history.append(cost)

    return theta, cost_history

# %%
#theta = np.zeros((X.shape[1], 1))

# %%
# theta, cost_history = gradient_descent(X, y, theta, alpha, iter)

# %%
# theta

# %%
# cost_history

# %%
cost_function(X, y, theta)
# Out:
# 0.6931471803610738

# %%
gd = gradient_descent(X,y,theta,alpha, iter)

# %%
gd
# Out:
# (array([11203645.33499997,  3404116.60074465]),
#  [-7838268.128209382,
#   -7838268.128209382,
#   -7838268.128209382,
#   -7838268.128209382,
#   -7838268.128209382,
#   -7838268.128209382,
#   -7838268.128209382,
#   -7838268.128209382,
#   -7838268.128209382,
#   -7838268.128209382,
#   -7838268.128209382,
#   -7838268.128209382,
#   -7838268.128209382,
#   -7838268.128209382,
#   -7838268.128209382,
#   -7838268.128209382,
#   -7838268.128209382,
#   -7838268.128209382,
#   -7838268.128209382,
#   -7838268.128209382,
#   -7838268.128209382,
#   -7838268.128209382,
#   -7838268.128209382,
#   -7838268.128209382,
#   -7838268.128209382,
#   -7838268.128209382,
#   -7838268.128209382,
#   -7838268.128209382,
#   -7838268.128209382,
#   -7838268.128209382,
#   -7838268.128209382,
#   -7838268.128209382,
#   -7838268.128209382,
#   -7838268.128209382,
#   -7838268.128209382,
#   -7838268.128209382,
#   -7838268.128209382,
#   -7838268.128209382,
#   -7838268.128209382,
# ...

# %%
t = [gd[0][0], gd[0][1]]
best_fit_x = np.linspace(0, 5, 10)
best_fit_y = [t[1] + t[0] * xx for xx in best_fit_x]

sns.regplot(x=best_fit_x, y=best_fit_y, data=data, logistic=True, ci=None)
# Out:
# <Axes: >
